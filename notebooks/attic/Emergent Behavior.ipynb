# %%
import Myro

# %%
Myro.init("sim")
robot = Myro.getRobot()
# Out:
# You are using:
#    Simulated Fluke, version 1.0.0
#    Simulated Scribbler 2, version 1.0.0
# Hello, my name is 'Scribby'!

# %%
Myro.getSimulation()
# Out:
# <Window (title='Myro Simulation',width=640,height=480)>

# %%
Myro.getSimulation().window.canvas.shapes.RemoveRange(5, 2)
Myro.getSimulation().window.canvas.shapes.RemoveAt(0)

# %%
Myro.setOption("show-sensors", True)

# %%
Myro.getSimulation()
# Out:
# <Window (title='Myro Simulation',width=640,height=480)>

# %%
robot.setPose(100, 250, 0)

# %%
Myro.getSimulation()
# Out:
# <Window (title='Myro Simulation',width=640,height=480)>

# %%
Myro.getSimulation().stop() # stop the simulation loop

# %%
robot.forward(1) # queues request to move

# %%
robot.update() # fires waiting requests

# %%
robot.setPose(100, 250, 0) # manually position robot

# %%
Myro.getSimulation().simulate(.1) # simulate some time

# %%
Myro.robot._getLocation() # normal robot.getLocation() would fire in robot.update()
# Out:
# [588.56451416015625, 250.29965209960938]

# %%
Myro.getSimulation()
# Out:
# <Window (title='Myro Simulation',width=640,height=480)>

# %%
Myro.getSimulation().setup() # starts loop up again

# %%
robot.stop()

# %%
import Myro
Myro.init("sim")
robot = Myro.getRobot()
Myro.setOption("show-sensors", True)
# Out:
# You are using:
#    Simulated Fluke, version 1.0.0
#    Simulated Scribbler 2, version 1.0.0
# Hello, my name is 'Scribby'!

# %%
from ai.governor import GovernorNetwork
net = GovernorNetwork(2, 0.1, 0.1) # size of inputs + outputs
net.addLayers(1, 3, 1)
trial_count = 0
count = 0
# Out:
# Conx using seed:
# 1397630527.13

# %%
robot.setPose(100, 250, 0)
net.setLearning(1)
t = 0

while True:
    count += 1
    target = 0.5
    obstacle = robot.getObstacle(1)
    distance = float(1 - obstacle/6400) 
    if distance < .5:
        target = 0.5
        if t == 0:
            robot.stop()
            t = Myro.currentTime()
        elif Myro.currentTime() - t >= 1.5:
            trial_count += 1
            robot.setPose(100, 250, 0)
            t = 0
        # else keep waiting
    elif distance < .8:
        target = .66
        robot.forward(.33)
    elif distance < .99:
        target = .83
        robot.forward(.66)
    else:
        target = 1.0
        robot.forward(1)
    results = net.step(input=[distance], output=[target])
    calico.animate("Trails: %s, Updates: %s" % (trial_count, count), str(net))
# Out:
# 'Trails: 23, Updates: 3088'
# 'Layer 'output': (Kind: Output, Size: 1, Active: 1, Frozen: 0)
# Target    : 0.83
# Activation: 0.89
# Layer 'hidden': (Kind: Hidden, Size: 3, Active: 1, Frozen: 0)
# Activation: 0.61  0.58  0.62
# Layer 'input': (Kind: Input, Size: 1, Active: 1, Frozen: 0)
# Activation: 0.82
# '
# Running script aborted!

# %%
net.setLearning(0)
robot.setPose(100, 250, 0)
tdata = []
ndata = []

# %%
def teacher(distance):
    if distance < .5:
        target = 0.5
    elif distance < .8:
        target = .66
    elif distance < .99:
        target = .83
    else:
        target = 1.0
    return target

# %%
while True:
    obstacle = robot.getObstacle(1)
    distance = float(1 - obstacle/6400) 
    results = net.propagate(input=[distance])
    ndata.append(results[0])
    tdata.append(teacher(distance))
    speed = (results[0] * 2) - 1.0
    robot.forward(speed)
    calico.animate(speed)
# Out:
# 0.00190958583420575
# Running script aborted!

# %%
from Widgets import Lines
size = len(tdata)
lines = Lines(size)
lines = Lines(lines, tdata, "Teacher")
lines = Lines(lines, ndata, "Network")
calico.display(calico.LineChart(lines))
# Out:
# <JavaScript viewable in executing notebook>
# Widgets+LineChart

# %%
robot.setPose(600, 250, 0)

# %%
net.setLearning(0)
net.propagate(input=[0.], output=[0.0])
print(net)
# Out:
# Layer 'output': (Kind: Output, Size: 1, Active: 1, Frozen: 0)
# Target    : 0.00
# Activation: 0.67
# Layer 'hidden': (Kind: Hidden, Size: 3, Active: 1, Frozen: 0)
# Activation: 0.41  0.42  0.41
# Layer 'input': (Kind: Input, Size: 1, Active: 1, Frozen: 0)
# Activation: 0.00

# %%
net.saveWeights("simple.wts")

# %%
net.loadWeights("simple.wts")

# %%
from Widgets import Lines, ScatterChart

# %%
for i in range(10):
    calico.animate(calico.ScatterChart(['x', 'Teacher', 'Network'], [[0, 0, 0], [1,1, 1], [1,2, 1], [1, .5, .25]], {"title": "Title"}))
# Out:
# Widgets+ScatterChart

# %%
lines = Lines(5, range(5))
# Out:
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
# TypeError: expected IList, got int

# %%
list(lines)
# Out:
# [List[object](['x', 'Line 1']), List[object](['1', 0]), List[object](['2', 1]), List[object](['3', 2]), List[object](['4', 3]), List[object](['5', 4])]
