# %%
calico.Audio("http://www.wavsource.com/snds_2014-01-26_2867841684548058/people/women/activity_unproductive.wav")

# %%
calico.Audio("/usr/lib/libreoffice/share/gallery/sounds/ok.wav")
# Out:
# <audio controls="controls" ><source controls src="data:audio/wav;base64,..." type="audio/wav" />Your browser does not support the audio element.</audio>

# %%
# %%%lang scheme
# Out:
# 'Calico Language is now "Scheme"'

# %%
(calico.Audio "/usr/lib/libreoffice/share/gallery/sounds/ok.wav")
# Out:
# <audio controls="controls" ><source controls src="data:audio/wav;base64,..." type="audio/wav" />Your browser does not support the audio element.</audio>
