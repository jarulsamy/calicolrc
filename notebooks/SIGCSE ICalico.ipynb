# %% [markdown]
# The Calico Project
# ------------------

# %% [markdown]
# <img src="data:image/png;base64,..."/>

# %%
# %%%lang console
# Out:
# Calico Language is now "Console"

# %%
pwd
# Out:
# /home/dblank/Calico/notebooks
# 'Ok'

# %%
cd ../languages
# Out:
# /home/dblank/Calico/languages
# 'Ok'

# %%
ls -l | cat -n
# Out:
#      1 /home/dblank/Calico/languages/Basic
#      2 /home/dblank/Calico/languages/Boo
#      3 /home/dblank/Calico/languages/BrainScrew
#      4 /home/dblank/Calico/languages/CSharp
#      5 /home/dblank/Calico/languages/Collaborate
#      6 /home/dblank/Calico/languages/Console
#      7 /home/dblank/Calico/languages/Dinah
#      8 /home/dblank/Calico/languages/Dot
#      9 /home/dblank/Calico/languages/FSharp
#     10 /home/dblank/Calico/languages/Images
#     11 /home/dblank/Calico/languages/Java
#     12 /home/dblank/Calico/languages/Jigsaw
#     13 /home/dblank/Calico/languages/LC3
#     14 /home/dblank/Calico/languages/Logo
#     15 /home/dblank/Calico/languages/Lua
#     16 /home/dblank/Calico/languages/Pascal
#     17 /home/dblank/Calico/languages/Python
#     18 /home/dblank/Calico/languages/Ruby
#     19 /home/dblank/Calico/languages/Scheme
#     20 /home/dblank/Calico/languages/Spreadsheet
#     21 /home/dblank/Calico/languages/Sympl
# 'Ok'
