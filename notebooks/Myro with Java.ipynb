# %%
:lang Java
# Out:
# 'Calico Language is now "Java"'

# %%
import Myro;

# %%
sim = new Myro.Simulation();

# %%
robot = (Myro.Robot)Myro.makeRobot("SimScribbler", sim);
# Out:
# You are using:
#    Simulated Fluke, version 1.0.0
#    Simulated Scribbler 2, version 1.0.0
# Hello, my name is 'Scribby'!

# %%
robot.forward(1,1);

# %%
Myro.getSimulation()
# Out:
# <Window (title='Myro Simulation',width=640,height=480)>

# %%
picture = robot.takePicture("");

# %%
picture
# Out:
# <Picture (width=256, height=192)>
