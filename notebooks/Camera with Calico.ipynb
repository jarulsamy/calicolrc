# %% [markdown]
# Getting a Camera image from your Computer
# -----------------------------------------
#
# 1. Make a CameraWidget
# 2. display it
# 3. turn it into a Picture

# %%
w = calico.makeCameraWidget()
# Out:
# Calico.MimeRepresentation

# %%
from Graphics import Picture
def f(value_name, value):
    calico.animate(Picture(w.imageurl))
    
w.on_value_change(f, "imageurl")

# %%
calico.display(w)
# Out:
# <Picture (width=320, height=240)>

# %%
picture = Picture(w.imageurl)

# %%
picture
# Out:
# <Picture (width=320, height=240)>

# %%
import Myro
for pixel in Myro.getPixels(picture):
    pixel.setRed(255)

# %%
picture
# Out:
# <Picture (width=320, height=240)>

# %% [markdown]
# Password Widget
# -----------------

# %%
pw = calico.makePasswordWidget()
calico.display(pw)

def f(obj):
    print(obj.value, "submitted!")
    
pw.on_submit(f)
# Out:
# Calico.MimeRepresentation
# this is a test
# submitted!

# %%
print(pw.value)
print(pw._view_name)
# Out:
# this is a test
# PasswordView
