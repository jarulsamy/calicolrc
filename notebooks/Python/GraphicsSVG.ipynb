# %%
from Myro import *
from Graphics import *

# %%
init('sim')
# Out:
# You are using:
#    Simulated Fluke, version 1.0.0
#    Simulated Scribbler 2, version 1.0.0
# Hello, my name is 'Scribby'!

# %%
w = getWindow()

# %%
p = takePicture()

# %%
Picture(w)
# Out:
# <Picture (width=640, height=480)>

# %%
p
# Out:
# <Picture (width=256, height=192)>

# %%
w.toSVG()
# Out:
# <SVG viewable in notebook>

# %%
from Graphics import *
import Myro

size = 300
win = Window("Turtle Graphics", size, size)
#win.setBackground(Color("white"))
turtle = Arrow((size/2, size/2), 0)
turtle.draw(win)
turtle.penDown()

def f(dist, angle, incr, segs):
  for i in range(segs):
    turtle.forward(dist * (size * .35))
    turtle.rotate(-angle)
    dist += incr

f(.01, 89.5, .01, 184)
#calico.SVG(win.toSVG())
win.saveToSVG("out.svg")

# %%
Picture(win)
# Out:
# <Picture (width=300, height=300)>

# %%
from Myro import *
from Graphics import *
w = Window(500, 500)
w.setBackground(Color(255, 255, 255))
#w.mode = "bitmap"
c = Circle((250, 250), 200)
c.setWidth(6)
c.draw(w)
Picture(w)
# Out:
# <Picture (width=500, height=500)>

# %%
w
# Out:
# <SVG viewable in notebook>

# %%
show(Picture(w))
