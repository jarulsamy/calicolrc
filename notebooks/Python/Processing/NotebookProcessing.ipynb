# %%
from Processing import *

# %%
window(500, 500)

# %%
background(0)

# %%
smooth()

# %%
stroke(96)

# %%
for i in range(100):
    ellipse(random(width()), random(height()), 5, 5)

# %%
def g():
    strokeWeight(4)
    line(mouseX(), mouseY(), pmouseX(), pmouseY())

# %%
onMouseDragged += g

# %%
loop()

# %%
mouseY()
# Out:
# 0

# %%
stroke(255, 0, 0)

# %%
def clear():
    background(0)
onKeyPressed += clear

# %%
v = get()

# %%
v

# %%
get()
