# %%
calico.Audio("http://www.nch.com.au/acm/11k16bitpcm.wav")
# Out:
# <audio controls="controls" ><source controls src="data:audio/wav;base64,..." type="audio/wav" />Your browser does not support the audio element.</audio>

# %%
calico.Audio("/Users/keithohara/calico/notebooksout.wav")
# Out:
# <audio controls="controls" ><source controls src="data:audio/wav;base64,..." type="audio/wav" />Your browser does not support the audio element.</audio>

# %%
# %%%lang scheme
# Out:
# Calico Language is now "Scheme"

# %%
(calico.Audio "/Users/keithohara/calico/notebooks/out.wav")
# Out:
# <audio controls="controls" ><source controls src="data:audio/wav;base64,..." type="audio/wav" />Your browser does not support the audio element.</audio>
