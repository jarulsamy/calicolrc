# %%
calico.HTML("<b>The <a href ='http://drablab.org'>draB</a> Lab</b>")
# Out:
# <HTML viewable in notebook>

# %%
calico.Image("http://drablab.org/logo8-small.png")
# Out:
# <Image: "http://drablab.org/logo8-small.png">
