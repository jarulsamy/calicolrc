# %%
from Graphics import Plot

plot = Plot("Sample Plot", 600, 300)
plot.xLabel.text = "time"
plot.yLabel.text = "balls in the air"

for data in [10, 30, 40, 50, 0, 100, 110, 40, 50]:
    plot.append(data)

# %%
plot
# Out:
# Graphics+Plot

# %%
from Graphics import Plot, wait

accum = []
for data in [10, 30, 40, 50, 0, 100, 110, 40, 50]:
    accum.append(data)
    plot = Plot("Sample Plot", 600, 300)
    plot.window.Iconify()
    plot.xLabel.text = "time"
    plot.yLabel.text = "balls in the air"
    for data in accum:
        plot.append(data)
    wait(.5)
    calico.clear_output()
    calico.display(plot)
# Out:
# Graphics+Plot

# %%
import Florence
import System

plot = Florence.GtkSharp.ImperativeHost()
#plot.Start()
x = System.Array[System.Double]([1.0, 2.0, 3.0])
y = System.Array[System.Double]([1.0, 2.0, 3.0])
z = System.Array[System.Double]([0.0, 2.0, 4.0])
plot.points(x, y)
plot.lines(x, z, title="Test Plot 2", x_label="X2", y_label="Y2")

# %%
from Graphics import Picture

# %%
dir(plot.ActiveFigure.PlotSurface)
# Out:
# ['Add', 'AddAxesConstraint', 'AddInteraction', 'AutoScaleAutoGeneratedAxes', 'AutoScaleTitle', 'CacheAxes', 'Clear', 'ClearAxisCache', 'DefineXAxes', 'DefineYAxes', 'DoDraw', 'DoKeyPress', 'DoKeyRelease', 'DoMouseDown', 'DoMouseEnter', 'DoMouseLeave', 'DoMouseMove', 'DoMouseScroll', 'DoMouseUp', 'Draw', 'DrawQueued', 'Drawables', 'Equals', 'Finalize', 'GetHashCode', 'GetType', 'HitTest', 'InteractionHandler', 'InteractionOccurred', 'Legend', 'LegendZOrder', 'MemberwiseClone', 'OnInteractionOccurred', 'OnPreRefresh', 'OuterBackColor', 'PhysicalXAxis1Cache', 'PhysicalXAxis2Cache', 'PhysicalYAxis1Cache', 'PhysicalYAxis2Cache', 'PlotAreaBoundingBoxCache', 'PlotBackBrush', 'PlotBackColor', 'PlotBackImage', 'PreRefresh', 'PreRefreshHandler', 'ProcessUpdates', 'QueueDraw', 'ReferenceEquals', 'Refresh', 'RefreshRequested', 'Remove', 'RemoveInteraction', 'SetOriginalDimensions', 'ShowCursor', 'SmoothingMode', 'SurfacePadding', 'Title', 'TitleBrush', 'TitleColor', 'TitleFont', 'ToString', 'Tra
# ...
